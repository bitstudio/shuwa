# %%
# %%capture
import tensorflow as tf
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
tf.__version__

# %% [markdown]
# ## Define tfkeras model

# %% [markdown]
# Only tfkeras tf-2.0.0+😉

# %%
def BlazeBlock(x, filters=16, kernel_size=3, strides=1, padding='same', name=None):
    
    
    x_l = DepthwiseConv2D(        
        kernel_size=kernel_size,
        strides=strides,
        padding=padding,
        use_bias=True)(x)
    
    # 1x1 
    x_l = Conv2D(
        filters=filters,
        kernel_size=1,
        strides=1,
        padding=padding,
        use_bias=True)(x_l)

    
    # max pooling
    if strides == 2:       
        input_channels = x.shape[-1]
        output_channels = x_l.shape[-1]

        
        x_r = MaxPooling2D(padding='same')(x)
      

        # channel padding
        num_channel_pads = output_channels - input_channels
        if num_channel_pads != 0:
            pads = tf.constant([[0, 0], [0, 0], [0, 0], [0, int(num_channel_pads)]])
            x_r = tf.pad(x_r, pads, "CONSTANT")


        out = Add()([x_l, x_r])
        return PReLU(shared_axes=[1, 2], name=name)(out)
    else: 
        
        out = Add()([x_l, x])        
        return PReLU(shared_axes=[1, 2], name=name)(out)

# %%
def FaceLandmarks(input_shape):

    inputs = tf.keras.layers.Input(shape=input_shape, name='input')

    # dummy ¯\_(ツ)_/¯
    cv0 = Conv2D(3,3)
    dw0 = DepthwiseConv2D(3)
    pr0 = PReLU()
    
    x = Conv2D(filters=16, kernel_size=3, strides=2, padding='valid')(inputs)   
    x = PReLU(shared_axes=[1, 2])(x)  
    x = BlazeBlock(x, filters=16)
    x = BlazeBlock(x, filters=16)

    x = BlazeBlock(x, filters=32, strides=2)
    x = BlazeBlock(x, filters=32)
    x = BlazeBlock(x, filters=32)

    x = BlazeBlock(x, filters=64, strides=2)
    x = BlazeBlock(x, filters=64)
    x = BlazeBlock(x, filters=64)

    x = BlazeBlock(x, filters=128, strides=2)
    x = BlazeBlock(x, filters=128)
    x = BlazeBlock(x, filters=128)

    x = BlazeBlock(x, filters=128, strides=2)
    x = BlazeBlock(x, filters=128)
    x = BlazeBlock(x, filters=128)
    
    
    # keypoints path.
    x_keyp = BlazeBlock(x, filters=128, strides=2)
    x_keyp = BlazeBlock(x_keyp, filters=128)
    x_keyp = BlazeBlock(x_keyp, filters=128)
    x_keyp = Conv2D(kernel_size=1, filters=32, padding='same')(x_keyp)
    x_keyp = PReLU(shared_axes=[1, 2])(x_keyp)
    x_keyp = BlazeBlock(x_keyp, filters=32)
    x_keyp = Conv2D(kernel_size=3, filters=1404)(x_keyp)
    
    
    
    
    # hack way to make the layer numering correct. ¯\_(ツ)_/¯
    dw18 = DepthwiseConv2D(3)
    dw19 = DepthwiseConv2D(3)
    dw20 = DepthwiseConv2D(3)
    dw21 = DepthwiseConv2D(3)
    cv21 = Conv2D(3,3)
    cv22 = Conv2D(3,3)
    cv23 = Conv2D(3,3)
    cv24 = Conv2D(3,3)
    cv25 = Conv2D(3,3)
    cv26 = Conv2D(3,3)
    mx5 = MaxPooling2D()
    pr20 = PReLU()
    pr21 = PReLU()
    pr22 = PReLU()
    pr23 = PReLU()
    pr24 = PReLU()
    
    
   
    
    # face flag path.
    x_flag = BlazeBlock(x, filters=128, strides=2)
    x_flag = Conv2D(kernel_size=1, filters=32, padding='same')(x_flag)
    x_flag = PReLU(shared_axes=[1, 2])(x_flag)
    
    x_flag = BlazeBlock(x_flag, filters=32)
    x_flag = Conv2D(kernel_size=3, filters=1)(x_flag)
    

    
    
    model = tf.keras.models.Model(inputs=inputs, outputs=[x_keyp, x_flag])
    return model

# %%
INPUT_SHAPE = (192, 192,3)
model = FaceLandmarks(INPUT_SHAPE)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 192, 192, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 95, 95, 16)   448         input[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 95, 95, 16)   16          conv2d_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 95, 95, 16)   160         p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 95, 95, 16)   272         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 95, 95, 16)   0           conv2d_2[0][0]
#                                                                  p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 95, 95, 16)   16          add[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 95, 95, 16)   160         p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 95, 95, 16)   272         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 95, 95, 16)   0           conv2d_3[0][0]
#                                                                  p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 95, 95, 16)   16          add_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 48, 48, 16)   160         p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 16)   0           p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 32)   544         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad (TFOpLambda)   (None, 48, 48, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 48, 48, 32)   0           conv2d_4[0][0]
#                                                                  tf.compat.v1.pad[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 48, 48, 32)   32          add_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 48, 48, 32)   320         p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 48, 32)   1056        depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 48, 48, 32)   0           conv2d_5[0][0]
#                                                                  p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 48, 48, 32)   32          add_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 48, 48, 32)   320         p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 32)   1056        depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 48, 48, 32)   0           conv2d_6[0][0]
#                                                                  p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 48, 48, 32)   32          add_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 24, 24, 32)   320         p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 32)   0           p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 24, 64)   2112        depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad_1 (TFOpLambda) (None, 24, 24, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 24, 24, 64)   0           conv2d_7[0][0]
#                                                                  tf.compat.v1.pad_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 24, 24, 64)   64          add_5[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 24, 24, 64)   640         p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 24, 64)   4160        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 24, 24, 64)   0           conv2d_8[0][0]
#                                                                  p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 24, 24, 64)   64          add_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 24, 24, 64)   640         p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 24, 24, 64)   4160        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 24, 24, 64)   0           conv2d_9[0][0]
#                                                                  p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 24, 24, 64)   64          add_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 12, 12, 64)   640         p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 64)   0           p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 12, 128)  8320        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad_2 (TFOpLambda) (None, 12, 12, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 128)  0           conv2d_10[0][0]
#                                                                  tf.compat.v1.pad_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 12, 12, 128)  128         add_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 12, 12, 128)  1280        p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 12, 12, 128)  16512       depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 12, 12, 128)  0           conv2d_11[0][0]
#                                                                  p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 12, 12, 128)  128         add_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 12, 12, 128)  1280        p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 12, 12, 128)  16512       depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 128)  0           conv2d_12[0][0]
#                                                                  p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 12, 12, 128)  128         add_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 6, 6, 128)    1280        p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 6, 6, 128)    16512       depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 128)    0           p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 6, 6, 128)    0           conv2d_13[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 6, 6, 128)    128         add_11[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 6, 6, 128)    1280        p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 6, 6, 128)    16512       depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 6, 6, 128)    0           conv2d_14[0][0]
#                                                                  p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 6, 6, 128)    128         add_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 6, 6, 128)    1280        p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 6, 6, 128)    16512       depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 6, 6, 128)    0           conv2d_15[0][0]
#                                                                  p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 6, 6, 128)    128         add_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 3, 3, 128)    1280        p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 3, 3, 128)    16512       depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 3, 3, 128)    0           p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 3, 3, 128)    0           conv2d_16[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 3, 3, 128)    128         add_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 3, 3, 128)    1280        p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 3, 3, 128)    16512       depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 3, 3, 128)    0           conv2d_17[0][0]
#                                                                  p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 3, 3, 128)    128         add_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 3, 3, 128)    1280        p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 3, 3, 128)    1280        p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 3, 3, 128)    16512       depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 3, 3, 128)    16512       depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 3, 3, 128)    0           p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 3, 3, 128)    0           conv2d_18[0][0]
#                                                                  p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 3, 3, 128)    0           conv2d_28[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, 3, 3, 128)    128         add_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_26 (PReLU)              (None, 3, 3, 128)    128         add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 3, 3, 32)     4128        p_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 3, 3, 32)     4128        p_re_lu_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_19 (PReLU)              (None, 3, 3, 32)     32          conv2d_19[0][0]
# __________________________________________________________________________________________________
# p_re_lu_27 (PReLU)              (None, 3, 3, 32)     32          conv2d_29[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 3, 3, 32)     320         p_re_lu_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 3, 3, 32)     320         p_re_lu_27[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 3, 3, 32)     1056        depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 3, 3, 32)     1056        depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 3, 3, 32)     0           conv2d_20[0][0]
#                                                                  p_re_lu_19[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 3, 3, 32)     0           conv2d_30[0][0]
#                                                                  p_re_lu_27[0][0]
# __________________________________________________________________________________________________
# p_re_lu_20 (PReLU)              (None, 3, 3, 32)     32          add_17[0][0]
# __________________________________________________________________________________________________
# p_re_lu_28 (PReLU)              (None, 3, 3, 32)     32          add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 1, 1, 1404)   405756      p_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 1, 1, 1)      289         p_re_lu_28[0][0]
# ==================================================================================================
# Total params: 604,685
# Trainable params: 604,685
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.save('model/face_landmark.h5')

# %%
model.save('model/saved_model', save_format='tf')

# %% [markdown]
# ## TFLite Weights convert.

# %%
import numpy as np
import tensorflow as tf

# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="model/face_landmark_new.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
all_layers_details = interpreter.get_tensor_details()

# %%
def correct_name(tflite_name):
    # change tflite layer name to keras name.
    if tflite_name.startswith('depthwise'):
        tflite_name = tflite_name.replace('Kernel', 'depthwise_kernel') 
    return tflite_name.lower()+":0"

# %%
weights_dict = {}
for layer in all_layers_details:
    if ('Kernel' in layer['name'] or 'Bias' in layer['name'] or 'Alpha' in layer['name']):

        keras_layer_name = correct_name(layer['name'])
        print(keras_layer_name)
        w = interpreter.get_tensor(layer['index'])
        weights_dict[keras_layer_name] = w
# Out:
# conv2d_1/kernel:0
# conv2d_1/bias:0
# p_re_lu_1/alpha:0
# depthwise_conv2d_1/depthwise_kernel:0
# depthwise_conv2d_1/bias:0
# conv2d_2/kernel:0
# conv2d_2/bias:0
# p_re_lu_2/alpha:0
# depthwise_conv2d_2/depthwise_kernel:0
# depthwise_conv2d_2/bias:0
# conv2d_3/kernel:0
# conv2d_3/bias:0
# p_re_lu_3/alpha:0
# depthwise_conv2d_3/depthwise_kernel:0
# depthwise_conv2d_3/bias:0
# conv2d_4/kernel:0
# conv2d_4/bias:0
# p_re_lu_4/alpha:0
# depthwise_conv2d_4/depthwise_kernel:0
# depthwise_conv2d_4/bias:0
# conv2d_5/kernel:0
# conv2d_5/bias:0
# p_re_lu_5/alpha:0
# depthwise_conv2d_5/depthwise_kernel:0
# depthwise_conv2d_5/bias:0
# conv2d_6/kernel:0
# conv2d_6/bias:0
# p_re_lu_6/alpha:0
# depthwise_conv2d_6/depthwise_kernel:0
# depthwise_conv2d_6/bias:0
# conv2d_7/kernel:0
# conv2d_7/bias:0
# p_re_lu_7/alpha:0
# depthwise_conv2d_7/depthwise_kernel:0
# depthwise_conv2d_7/bias:0
# conv2d_8/kernel:0
# conv2d_8/bias:0
# p_re_lu_8/alpha:0
# depthwise_conv2d_8/depthwise_kernel:0
# depthwise_conv2d_8/bias:0
# conv2d_9/kernel:0
# conv2d_9/bias:0
# p_re_lu_9/alpha:0
# depthwise_conv2d_9/depthwise_kernel:0
# depthwise_conv2d_9/bias:0
# conv2d_10/kernel:0
# conv2d_10/bias:0
# p_re_lu_10/alpha:0
# depthwise_conv2d_10/depthwise_kernel:0
# depthwise_conv2d_10/bias:0
# conv2d_11/kernel:0
# conv2d_11/bias:0
# p_re_lu_11/alpha:0
# depthwise_conv2d_11/depthwise_kernel:0
# depthwise_conv2d_11/bias:0
# conv2d_12/kernel:0
# conv2d_12/bias:0
# p_re_lu_12/alpha:0
# depthwise_conv2d_12/depthwise_kernel:0
# depthwise_conv2d_12/bias:0
# conv2d_13/kernel:0
# conv2d_13/bias:0
# p_re_lu_13/alpha:0
# depthwise_conv2d_13/depthwise_kernel:0
# depthwise_conv2d_13/bias:0
# conv2d_14/kernel:0
# conv2d_14/bias:0
# p_re_lu_14/alpha:0
# depthwise_conv2d_14/depthwise_kernel:0
# depthwise_conv2d_14/bias:0
# conv2d_15/kernel:0
# conv2d_15/bias:0
# p_re_lu_15/alpha:0
# depthwise_conv2d_15/depthwise_kernel:0
# depthwise_conv2d_15/bias:0
# conv2d_16/kernel:0
# conv2d_16/bias:0
# p_re_lu_16/alpha:0
# depthwise_conv2d_16/depthwise_kernel:0
# depthwise_conv2d_16/bias:0
# conv2d_17/kernel:0
# conv2d_17/bias:0
# p_re_lu_17/alpha:0
# depthwise_conv2d_23/depthwise_kernel:0
# depthwise_conv2d_23/bias:0
# depthwise_conv2d_17/depthwise_kernel:0
# depthwise_conv2d_17/bias:0
# conv2d_28/kernel:0
# conv2d_28/bias:0
# conv2d_18/kernel:0
# conv2d_18/bias:0
# p_re_lu_26/alpha:0
# p_re_lu_18/alpha:0
# conv2d_29/kernel:0
# conv2d_29/bias:0
# conv2d_19/kernel:0
# conv2d_19/bias:0
# p_re_lu_27/alpha:0
# p_re_lu_19/alpha:0
# depthwise_conv2d_24/depthwise_kernel:0
# depthwise_conv2d_24/bias:0
# depthwise_conv2d_18/depthwise_kernel:0
# depthwise_conv2d_18/bias:0
# conv2d_30/kernel:0
# conv2d_30/bias:0
# conv2d_20/kernel:0
# conv2d_20/bias:0
# p_re_lu_28/alpha:0
# p_re_lu_20/alpha:0
# conv2d_31/kernel:0
# conv2d_31/bias:0
# conv2d_21/kernel:0
# conv2d_21/bias:0

# %%
for each_layer in model.layers:
    # conv2d
#     print("="*10, each_layer.name)
    
    if hasattr(each_layer, 'depthwise_kernel') and each_layer.depthwise_kernel is not None:    
        #print('depth wise convolution')
        K.set_value(each_layer.weights[0], weights_dict[each_layer.name+'/depthwise_kernel:0'].transpose(1,2,3,0));print(each_layer.name+'.weight')
    
    
    
    if hasattr(each_layer, 'kernel') and each_layer.kernel is not None:        
        if len(weights_dict[each_layer.name+'/kernel:0'].shape) == 4:   
            #print('normal 2d convolution')
            K.set_value(each_layer.weights[0], weights_dict[each_layer.name+'/kernel:0'].transpose(1,2,3,0));print(each_layer.name+'.weight')
        
            
    if hasattr(each_layer, 'bias') and each_layer.bias is not None:
        K.set_value(each_layer.weights[1], weights_dict[each_layer.name+'/bias:0']);print(each_layer.name+'.bias')
        
    if hasattr(each_layer, 'alpha') and each_layer.alpha is not None:
        K.set_value(each_layer.weights[0], weights_dict[each_layer.name+'/alpha:0']);print(each_layer.name+'.alpha')
# Out:
# conv2d_1.weight
# conv2d_1.bias
# p_re_lu_1.alpha
# depthwise_conv2d_1.weight
# depthwise_conv2d_1.bias
# conv2d_2.weight
# conv2d_2.bias
# p_re_lu_2.alpha
# depthwise_conv2d_2.weight
# depthwise_conv2d_2.bias
# conv2d_3.weight
# conv2d_3.bias
# p_re_lu_3.alpha
# depthwise_conv2d_3.weight
# depthwise_conv2d_3.bias
# conv2d_4.weight
# conv2d_4.bias
# p_re_lu_4.alpha
# depthwise_conv2d_4.weight
# depthwise_conv2d_4.bias
# conv2d_5.weight
# conv2d_5.bias
# p_re_lu_5.alpha
# depthwise_conv2d_5.weight
# depthwise_conv2d_5.bias
# conv2d_6.weight
# conv2d_6.bias
# p_re_lu_6.alpha
# depthwise_conv2d_6.weight
# depthwise_conv2d_6.bias
# conv2d_7.weight
# conv2d_7.bias
# p_re_lu_7.alpha
# depthwise_conv2d_7.weight
# depthwise_conv2d_7.bias
# conv2d_8.weight
# conv2d_8.bias
# p_re_lu_8.alpha
# depthwise_conv2d_8.weight
# depthwise_conv2d_8.bias
# conv2d_9.weight
# conv2d_9.bias
# p_re_lu_9.alpha
# depthwise_conv2d_9.weight
# depthwise_conv2d_9.bias
# conv2d_10.weight
# conv2d_10.bias
# p_re_lu_10.alpha
# depthwise_conv2d_10.weight
# depthwise_conv2d_10.bias
# conv2d_11.weight
# conv2d_11.bias
# p_re_lu_11.alpha
# depthwise_conv2d_11.weight
# depthwise_conv2d_11.bias
# conv2d_12.weight
# conv2d_12.bias
# p_re_lu_12.alpha
# depthwise_conv2d_12.weight
# depthwise_conv2d_12.bias
# conv2d_13.weight
# conv2d_13.bias
# p_re_lu_13.alpha
# depthwise_conv2d_13.weight
# depthwise_conv2d_13.bias
# conv2d_14.weight
# conv2d_14.bias
# p_re_lu_14.alpha
# depthwise_conv2d_14.weight
# depthwise_conv2d_14.bias
# conv2d_15.weight
# conv2d_15.bias
# p_re_lu_15.alpha
# depthwise_conv2d_15.weight
# depthwise_conv2d_15.bias
# conv2d_16.weight
# conv2d_16.bias
# p_re_lu_16.alpha
# depthwise_conv2d_16.weight
# depthwise_conv2d_16.bias
# conv2d_17.weight
# conv2d_17.bias
# p_re_lu_17.alpha
# depthwise_conv2d_17.weight
# depthwise_conv2d_17.bias
# depthwise_conv2d_23.weight
# depthwise_conv2d_23.bias
# conv2d_18.weight
# conv2d_18.bias
# conv2d_28.weight
# conv2d_28.bias
# p_re_lu_18.alpha
# p_re_lu_26.alpha
# conv2d_19.weight
# conv2d_19.bias
# conv2d_29.weight
# conv2d_29.bias
# p_re_lu_19.alpha
# p_re_lu_27.alpha
# depthwise_conv2d_18.weight
# depthwise_conv2d_18.bias
# depthwise_conv2d_24.weight
# depthwise_conv2d_24.bias
# conv2d_20.weight
# conv2d_20.bias
# conv2d_30.weight
# conv2d_30.bias
# p_re_lu_20.alpha
# p_re_lu_28.alpha
# conv2d_21.weight
# conv2d_21.bias
# conv2d_31.weight
# conv2d_31.bias
