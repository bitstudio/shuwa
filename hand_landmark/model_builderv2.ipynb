# %%
# %%capture
import tensorflow as tf
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
tf.__version__

# %% [markdown]
# ## Define tfkeras model

# %% [markdown]
# Only tfkeras tf-2.0.0+😉

# %%
def MobileBlock(x, inter_filters=96, out_filters=16, kernel_size=5, strides=1, skip=False):     
    
    # 1x1 
    x_r = Conv2D(filters=inter_filters, kernel_size=1, padding='same')(x) 
    x_r = ReLU(6.0)(x_r)
    
    # dw
    x_r = DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding='same')(x_r)
    x_r = ReLU(6.0)(x_r)
    
    # 1x1 
    x_r = Conv2D(filters=out_filters, kernel_size=1, padding='same', activation=None)(x_r)   

    if skip:
        return Add()([x, x_r])
    else:
        return x_r

# %%
def Hand3D(input_shape):

    inputs = tf.keras.layers.Input(shape=input_shape, name='input')

    # first block
    x = Conv2D(filters=24, kernel_size=3, strides=2, padding='same')(inputs)   
    x = ReLU(6.0)(x)
    x = DepthwiseConv2D(kernel_size=3, strides=1, padding='same')(x)
    x = ReLU(6.0)(x)
    x = Conv2D(filters=8, kernel_size=1, padding='same', activation=None)(x)   
            
  
    x = MobileBlock(x, inter_filters=32, out_filters=16, kernel_size=3, strides=2)
    x = MobileBlock(x, inter_filters=96, out_filters=16, kernel_size=3, skip=True)
    
    x = MobileBlock(x, inter_filters=96, out_filters=24, kernel_size=5,  strides=2)
    x = MobileBlock(x, inter_filters=144, out_filters=24, kernel_size=5, skip=True)
    
    x = MobileBlock(x, inter_filters=144, out_filters=40, kernel_size=3, strides=2)
    x = MobileBlock(x, inter_filters=240, out_filters=40, kernel_size=3, skip=True)    
    x = MobileBlock(x, inter_filters=240, out_filters=40, kernel_size=3, skip=True)
    
    x = MobileBlock(x, inter_filters=240, out_filters=56, kernel_size=5, strides=1)
    x = MobileBlock(x, inter_filters=336, out_filters=56, kernel_size=5, skip=True)    
    x = MobileBlock(x, inter_filters=336, out_filters=56, kernel_size=5, skip=True)
    
    x = MobileBlock(x, inter_filters=336, out_filters=96, kernel_size=5, strides=2)
    x = MobileBlock(x, inter_filters=576, out_filters=96, kernel_size=5, skip=True)    
    x = MobileBlock(x, inter_filters=576, out_filters=96, kernel_size=5, skip=True)
    x = MobileBlock(x, inter_filters=576, out_filters=96, kernel_size=5, skip=True)
    
    
    # ending block
    x = Conv2D(filters=576, kernel_size=1, strides=1, padding='same')(x)   
    x = ReLU(6.0)(x)
    x = DepthwiseConv2D(kernel_size=3, strides=1, padding='same')(x)
    x = ReLU(6.0)(x)
    x = DepthwiseConv2D(kernel_size=3, strides=2, padding='same')(x)
    x = ReLU(6.0)(x)
    x = Conv2D(filters=144, kernel_size=1, padding='same', activation=None)(x)    
    x = Flatten()(x)

    # output head
    handflag = Dense(1, activation='sigmoid', name='handflag')(x)
    handedness = Dense(1, activation='sigmoid', name='handedness')(x)    
    landmarks = Dense(63, name='landmarks')(x)

    
    model = tf.keras.models.Model(inputs=inputs, outputs=[handflag, handedness, landmarks])
    return model

# %%
INPUT_SHAPE = (224, 224,3)
model = Hand3D(INPUT_SHAPE)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 24) 672         input[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 112, 112, 24) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 112, 112, 24) 240         re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 112, 112, 24) 0           depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 8)  200         re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 32) 288         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 112, 112, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 56, 56, 32)   320         re_lu_2[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 56, 56, 32)   0           depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 16)   528         re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 96)   1632        conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 56, 56, 96)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 56, 56, 96)   960         re_lu_4[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 56, 56, 96)   0           depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 16)   1552        re_lu_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 16)   0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 96)   1632        add[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 56, 56, 96)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 28, 28, 96)   2496        re_lu_6[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 28, 28, 96)   0           depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 24)   2328        re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 144)  3600        conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 28, 28, 144)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 28, 28, 144)  3744        re_lu_8[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 28, 28, 144)  0           depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 24)   3480        re_lu_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 24)   0           conv2d_7[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 144)  3600        add_1[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 28, 28, 144)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 14, 14, 144)  1440        re_lu_10[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 14, 14, 144)  0           depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 40)   5800        re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 240)  9840        conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 14, 14, 240)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 14, 14, 240)  2400        re_lu_12[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 14, 14, 240)  0           depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 40)   9640        re_lu_13[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 40)   0           conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 240)  9840        add_2[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 14, 14, 240)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 14, 14, 240)  2400        re_lu_14[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 14, 14, 240)  0           depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 40)   9640        re_lu_15[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 40)   0           add_2[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 240)  9840        add_3[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 14, 14, 240)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 14, 14, 240)  6240        re_lu_16[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 14, 14, 240)  0           depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 56)   13496       re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 336)  19152       conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 14, 14, 336)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 14, 14, 336)  8736        re_lu_18[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 14, 14, 336)  0           depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 56)   18872       re_lu_19[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 56)   0           conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 336)  19152       add_4[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 14, 14, 336)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 14, 14, 336)  8736        re_lu_20[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 14, 14, 336)  0           depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 56)   18872       re_lu_21[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 56)   0           add_4[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 336)  19152       add_5[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 14, 14, 336)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 7, 7, 336)    8736        re_lu_22[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 7, 7, 336)    0           depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 7, 7, 96)     32352       re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 7, 7, 576)    55872       conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 7, 7, 576)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 7, 7, 576)    14976       re_lu_24[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 7, 7, 576)    0           depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 7, 7, 96)     55392       re_lu_25[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 96)     0           conv2d_23[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 7, 7, 576)    55872       add_6[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 7, 7, 576)    0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 7, 7, 576)    14976       re_lu_26[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 7, 7, 576)    0           depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 7, 7, 96)     55392       re_lu_27[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 96)     0           add_6[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 7, 7, 576)    55872       add_7[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 7, 7, 576)    0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 7, 7, 576)    14976       re_lu_28[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 7, 7, 576)    0           depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 7, 7, 96)     55392       re_lu_29[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 96)     0           add_7[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 7, 7, 576)    55872       add_8[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 7, 7, 576)    0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 7, 7, 576)    5760        re_lu_30[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 7, 7, 576)    0           depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 4, 4, 576)    5760        re_lu_31[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 4, 4, 576)    0           depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 144)    83088       re_lu_32[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2304)         0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# handflag (Dense)                (None, 1)            2305        flatten[0][0]
# __________________________________________________________________________________________________
# handedness (Dense)              (None, 1)            2305        flatten[0][0]
# __________________________________________________________________________________________________
# landmarks (Dense)               (None, 63)           145215      flatten[0][0]
# ==================================================================================================
# Total params: 940,633
# Trainable params: 940,633
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.save('model/new_blank.h5')

# %%
model.save('model/saved_model',save_format='tf')

# %% [markdown]
# ## TFLite Weights convert.

# %%
import glob, os
import numpy as np

# %%
np_files = glob.glob("model/w/*.npy")
weights_dict = {}
for f in np_files:
    name = os.path.split(f)[-1].replace(".kernel", "/kernel:0").replace(".bias", "/bias:0").replace(".npy", "")
    if "depthwise" in name:
        name = name.replace("/kernel:0", "/depthwise_kernel:0")    
    
    weight = np.load(f)
    weights_dict[name] = weight
weights_dict.keys()
# Out:
# dict_keys(['conv2d/bias:0', 'conv2d/kernel:0', 'conv2d_1/bias:0', 'conv2d_1/kernel:0', 'conv2d_10/bias:0', 'conv2d_10/kernel:0', 'conv2d_11/bias:0', 'conv2d_11/kernel:0', 'conv2d_12/bias:0', 'conv2d_12/kernel:0', 'conv2d_13/bias:0', 'conv2d_13/kernel:0', 'conv2d_14/bias:0', 'conv2d_14/kernel:0', 'conv2d_15/bias:0', 'conv2d_15/kernel:0', 'conv2d_16/bias:0', 'conv2d_16/kernel:0', 'conv2d_17/bias:0', 'conv2d_17/kernel:0', 'conv2d_18/bias:0', 'conv2d_18/kernel:0', 'conv2d_19/bias:0', 'conv2d_19/kernel:0', 'conv2d_2/bias:0', 'conv2d_2/kernel:0', 'conv2d_20/bias:0', 'conv2d_20/kernel:0', 'conv2d_21/bias:0', 'conv2d_21/kernel:0', 'conv2d_22/bias:0', 'conv2d_22/kernel:0', 'conv2d_23/bias:0', 'conv2d_23/kernel:0', 'conv2d_24/bias:0', 'conv2d_24/kernel:0', 'conv2d_25/bias:0', 'conv2d_25/kernel:0', 'conv2d_26/bias:0', 'conv2d_26/kernel:0', 'conv2d_27/bias:0', 'conv2d_27/kernel:0', 'conv2d_28/bias:0', 'conv2d_28/kernel:0', 'conv2d_29/bias:0', 'conv2d_29/kernel:0', 'conv2d_3/bias:0', 'conv2d_3/kernel:0', 'conv2d_30/bias:0', 'conv2d_30/kernel:0', 'conv2d_31/bias:0', 'conv2d_31/kernel:0', 'conv2d_4/bias:0', 'conv2d_4/kernel:0', 'conv2d_5/bias:0', 'conv2d_5/kernel:0', 'conv2d_6/bias:0', 'conv2d_6/kernel:0', 'conv2d_7/bias:0', 'conv2d_7/kernel:0', 'conv2d_8/bias:0', 'conv2d_8/kernel:0', 'conv2d_9/bias:0', 'conv2d_9/kernel:0', 'depthwise_conv2d/bias:0', 'depthwise_conv2d/depthwise_kernel:0', 'depthwise_conv2d_1/bias:0', 'depthwise_conv2d_1/depthwise_kernel:0', 'depthwise_conv2d_10/bias:0', 'depthwise_conv2d_10/depthwise_kernel:0', 'depthwise_conv2d_11/bias:0', 'depthwise_conv2d_11/depthwise_kernel:0', 'depthwise_conv2d_12/bias:0', 'depthwise_conv2d_12/depthwise_kernel:0', 'depthwise_conv2d_13/bias:0', 'depthwise_conv2d_13/depthwise_kernel:0', 'depthwise_conv2d_14/bias:0', 'depthwise_conv2d_14/depthwise_kernel:0', 'depthwise_conv2d_15/bias:0', 'depthwise_conv2d_15/depthwise_kernel:0', 'depthwise_conv2d_16/bias:0', 'depthwise_conv2d_16/depthwise_kernel:0', 'depthwise_conv2d_2/bias:0', 'depthwise_conv2d_2/depthwise_kernel:0', 'depthwise_conv2d_3/bias:0', 'depthwise_conv2d_3/depthwise_kernel:0', 'depthwise_conv2d_4/bias:0', 'depthwise_conv2d_4/depthwise_kernel:0', 'depthwise_conv2d_5/bias:0', 'depthwise_conv2d_5/depthwise_kernel:0', 'depthwise_conv2d_6/bias:0', 'depthwise_conv2d_6/depthwise_kernel:0', 'depthwise_conv2d_7/bias:0', 'depthwise_conv2d_7/depthwise_kernel:0', 'depthwise_conv2d_8/bias:0', 'depthwise_conv2d_8/depthwise_kernel:0', 'depthwise_conv2d_9/bias:0', 'depthwise_conv2d_9/depthwise_kernel:0', 'handedness/bias:0', 'handedness/kernel:0', 'handflag/bias:0', 'handflag/kernel:0', 'landmarks/bias:0', 'landmarks/kernel:0'])

# %%
count = 0
for each_layer in model.layers:    
    if hasattr(each_layer, 'depthwise_kernel') and each_layer.depthwise_kernel is not None:    
        K.set_value(each_layer.weights[0], weights_dict[each_layer.name+'/depthwise_kernel:0'].transpose(1,2,3,0))
        print(each_layer.name+'.weight')
        count += 1
    
    if hasattr(each_layer, 'kernel') and each_layer.kernel is not None:        
        if len(weights_dict[each_layer.name+'/kernel:0'].shape) == 4:   
            K.set_value(each_layer.weights[0], weights_dict[each_layer.name+'/kernel:0'].transpose(1,2,3,0))            
            
        else:
            K.set_value(each_layer.weights[0], weights_dict[each_layer.name+'/kernel:0'].transpose(1,0))
            
        print(each_layer.name+'.weight')
        count += 1
    if hasattr(each_layer, 'bias') and each_layer.bias is not None:
        K.set_value(each_layer.weights[1], weights_dict[each_layer.name+'/bias:0'])
        print(each_layer.name+'.bias')
        count += 1
# Out:
# conv2d.weight
# conv2d.bias
# depthwise_conv2d.weight
# depthwise_conv2d.bias
# conv2d_1.weight
# conv2d_1.bias
# conv2d_2.weight
# conv2d_2.bias
# depthwise_conv2d_1.weight
# depthwise_conv2d_1.bias
# conv2d_3.weight
# conv2d_3.bias
# conv2d_4.weight
# conv2d_4.bias
# depthwise_conv2d_2.weight
# depthwise_conv2d_2.bias
# conv2d_5.weight
# conv2d_5.bias
# conv2d_6.weight
# conv2d_6.bias
# depthwise_conv2d_3.weight
# depthwise_conv2d_3.bias
# conv2d_7.weight
# conv2d_7.bias
# conv2d_8.weight
# conv2d_8.bias
# depthwise_conv2d_4.weight
# depthwise_conv2d_4.bias
# conv2d_9.weight
# conv2d_9.bias
# conv2d_10.weight
# conv2d_10.bias
# depthwise_conv2d_5.weight
# depthwise_conv2d_5.bias
# conv2d_11.weight
# conv2d_11.bias
# conv2d_12.weight
# conv2d_12.bias
# depthwise_conv2d_6.weight
# depthwise_conv2d_6.bias
# conv2d_13.weight
# conv2d_13.bias
# conv2d_14.weight
# conv2d_14.bias
# depthwise_conv2d_7.weight
# depthwise_conv2d_7.bias
# conv2d_15.weight
# conv2d_15.bias
# conv2d_16.weight
# conv2d_16.bias
# depthwise_conv2d_8.weight
# depthwise_conv2d_8.bias
# conv2d_17.weight
# conv2d_17.bias
# conv2d_18.weight
# conv2d_18.bias
# depthwise_conv2d_9.weight
# depthwise_conv2d_9.bias
# conv2d_19.weight
# conv2d_19.bias
# conv2d_20.weight
# conv2d_20.bias
# depthwise_conv2d_10.weight
# depthwise_conv2d_10.bias
# conv2d_21.weight
# conv2d_21.bias
# conv2d_22.weight
# conv2d_22.bias
# depthwise_conv2d_11.weight
# depthwise_conv2d_11.bias
# conv2d_23.weight
# conv2d_23.bias
# conv2d_24.weight
# conv2d_24.bias
# depthwise_conv2d_12.weight
# depthwise_conv2d_12.bias
# conv2d_25.weight
# conv2d_25.bias
# conv2d_26.weight
# conv2d_26.bias
# depthwise_conv2d_13.weight
# depthwise_conv2d_13.bias
# conv2d_27.weight
# conv2d_27.bias
# conv2d_28.weight
# conv2d_28.bias
# depthwise_conv2d_14.weight
# depthwise_conv2d_14.bias
# conv2d_29.weight
# conv2d_29.bias
# conv2d_30.weight
# conv2d_30.bias
# depthwise_conv2d_15.weight
# depthwise_conv2d_15.bias
# depthwise_conv2d_16.weight
# depthwise_conv2d_16.bias
# conv2d_31.weight
# conv2d_31.bias
# handflag.weight
# handflag.bias
# handedness.weight
# handedness.bias
# landmarks.weight
# landmarks.bias

# %%
count
# Out:
# 104
